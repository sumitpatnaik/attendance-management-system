# %%
from utils import Conf
from imutils import paths
import face_recognition
import argparse
import pickle
import cv2
import os
config_file="D:/Attendance Management System/config/config.json"
conf = Conf(config_file)

print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images(
os.path.join(conf["dataset_path"], conf["class"])))
knownEncodings = []
knownNames = []
for (i, imagePath) in enumerate(imagePaths):
	print("[INFO] processing image {}/{}".format(i + 1,
	len(imagePaths)))
	name = imagePath.split(os.path.sep)[-2]
    
	image = cv2.imread(imagePath)
	rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	encodings = face_recognition.face_encodings(rgb)

	for encoding in encodings:
		knownEncodings.append(encoding)
		knownNames.append(name)
print("[INFO] serializing encodings...")
data = {"encodings": knownEncodings, "names": knownNames}
f = open(conf["encodings_path"], "wb")
f.write(pickle.dumps(data))
f.close()
# Out:
# Requirement already satisfied: json_minify in c:\users\sumit\anaconda3\envs\opencv\lib\site-packages (0.3.0)
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Processing c:\users\sumit\appdata\local\pip\cache\wheels\d2\99\18\59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f\face_recognition_models-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Click>=6.0 in c:\users\sumit\anaconda3\envs\opencv\lib\site-packages (from face_recognition) (7.1.1)
# Requirement already satisfied: numpy in c:\users\sumit\anaconda3\envs\opencv\lib\site-packages (from face_recognition) (1.16.6)
# Collecting dlib>=19.7
#   Using cached dlib-19.20.0.tar.gz (3.2 MB)
# Requirement already satisfied: Pillow in c:\users\sumit\anaconda3\envs\opencv\lib\site-packages (from face_recognition) (7.1.1)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: face-recognition-models, dlib, face-recognition
#     Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\sumit\Anaconda3\envs\opencv\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\setup.py'"'"'; __file__='"'"'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\sumit\AppData\Local\Temp\pip-wheel-8kewwei5'
#        cwd: C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\
#   Complete output (55 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   Building extension for Python 3.7.7 (default, Mar 23 2020, 23:19:08) [MSC v.1916 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\build\lib.win-amd64-3.7 -DPYTHON_EXECUTABLE=C:\Users\sumit\Anaconda3\envs\opencv\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\build\lib.win-amd64-3.7 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:3 (project):
#     Generator
#
#       NMake Makefiles
#
#     does not support platform specification, but platform
#
#       x64
#
#     was specified.
#
#
#   CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#   CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#   -- Configuring incomplete, errors occurred!
#   See also "C:/Users/sumit/AppData/Local/Temp/pip-install-sp8mvyu_/dlib/build/temp.win-amd64-3.7/Release/CMakeFiles/CMakeOutput.log".
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\setup.py", line 261, in <module>
#       'Topic :: Software Development',
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\site-packages\setuptools\__init__.py", line 144, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\site-packages\wheel\bdist_wheel.py", line 223, in run
#       self.run_command('build')
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\setup.py", line 135, in run
#       self.build_extension(ext)
#     File "C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\setup.py", line 172, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "C:\Users\sumit\Anaconda3\envs\opencv\lib\subprocess.py", line 363, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\build\\lib.win-amd64-3.7', '-DPYTHON_EXECUTABLE=C:\\Users\\sumit\\Anaconda3\\envs\\opencv\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\build\\lib.win-amd64-3.7', '-A', 'x64']' returned non-zero exit status 1.
#   ----------------------------------------
#   ERROR: Failed building wheel for dlib
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\sumit\Anaconda3\envs\opencv\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\setup.py'"'"'; __file__='"'"'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\sumit\AppData\Local\Temp\pip-record-x6glc0ui\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\sumit\Anaconda3\envs\opencv\Include\dlib'
#          cwd: C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\
#     Complete output (57 lines):
#     running install
#     running build
#     running build_py
#     package init file 'dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#     Building extension for Python 3.7.7 (default, Mar 23 2020, 23:19:08) [MSC v.1916 64 bit (AMD64)]
#     Invoking CMake setup: 'cmake C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\build\lib.win-amd64-3.7 -DPYTHON_EXECUTABLE=C:\Users\sumit\Anaconda3\envs\opencv\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\build\lib.win-amd64-3.7 -A x64'
#     -- Building for: NMake Makefiles
#     CMake Error at CMakeLists.txt:3 (project):
#       Generator
#
#         NMake Makefiles
#
#       does not support platform specification, but platform
#
#         x64
#
#       was specified.
#
#
#     CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#     CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#     -- Configuring incomplete, errors occurred!
#     See also "C:/Users/sumit/AppData/Local/Temp/pip-install-sp8mvyu_/dlib/build/temp.win-amd64-3.7/Release/CMakeFiles/CMakeOutput.log".
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\setup.py", line 261, in <module>
#         'Topic :: Software Development',
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\site-packages\setuptools\__init__.py", line 144, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\setup.py", line 135, in run
#         self.build_extension(ext)
#       File "C:\Users\sumit\AppData\Local\Temp\pip-install-sp8mvyu_\dlib\setup.py", line 172, in build_extension
#         subprocess.check_call(cmake_setup, cwd=build_folder)
#       File "C:\Users\sumit\Anaconda3\envs\opencv\lib\subprocess.py", line 363, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\build\\lib.win-amd64-3.7', '-DPYTHON_EXECUTABLE=C:\\Users\\sumit\\Anaconda3\\envs\\opencv\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\build\\lib.win-amd64-3.7', '-A', 'x64']' returned non-zero exit status 1.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\sumit\Anaconda3\envs\opencv\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\setup.py'"'"'; __file__='"'"'C:\\Users\\sumit\\AppData\\Local\\Temp\\pip-install-sp8mvyu_\\dlib\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\sumit\AppData\Local\Temp\pip-record-x6glc0ui\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\sumit\Anaconda3\envs\opencv\Include\dlib' Check the logs for full command output.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-e2707a3edcbd> in <module>
#      16 from utils import Conf
#      17 from imutils import paths
# ---> 18 import face_recognition
#      19 import argparse
#      20 import pickle
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
import os
dire=list("")
